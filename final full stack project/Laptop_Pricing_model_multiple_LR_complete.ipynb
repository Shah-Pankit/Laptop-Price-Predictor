# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error ,  mean_squared_error
from sklearn.preprocessing import OneHotEncoder
import joblib
from math import sqrt

# %%
data=pd.read_csv("laptop_pricing_dataset.csv")
data
# Out:
#      Unnamed: 0 Manufacturer  Category     Screen  GPU  OS  CPU_core  \
# 0             0         Acer         4  IPS Panel    2   1         5
# 1             1         Dell         3    Full HD    1   1         3
# 2             2         Dell         3    Full HD    1   1         7
# 3             3         Dell         4  IPS Panel    2   1         5
# 4             4           HP         4    Full HD    2   1         7
# ..          ...          ...       ...        ...  ...  ..       ...
# 233         233       Lenovo         4  IPS Panel    2   1         7
# 234         234      Toshiba         3    Full HD    2   1         5
# 235         235       Lenovo         4  IPS Panel    2   1         5
# 236         236       Lenovo         3    Full HD    3   1         5
# 237         237      Toshiba         3    Full HD    2   1         5
#
#      Screen_Size_cm  CPU_frequency  RAM_GB  Storage_GB_SSD  Weight_kg  Price
# ...

# %%
columns=['Manufacturer','GPU','CPU_core','RAM_GB','Storage_GB_SSD','Price']
columns
# Out:
# ['Manufacturer', 'GPU', 'CPU_core', 'RAM_GB', 'Storage_GB_SSD', 'Price']

# %%
new_data=data[columns]
new_data
# Out:
#     Manufacturer  GPU  CPU_core  RAM_GB  Storage_GB_SSD  Price
# 0           Acer    2         5       8             256    978
# 1           Dell    1         3       4             256    634
# 2           Dell    1         7       8             256    946
# 3           Dell    2         5       8             128   1244
# 4             HP    2         7       8             256    837
# ..           ...  ...       ...     ...             ...    ...
# 233       Lenovo    2         7       8             256   1891
# 234      Toshiba    2         5       8             256   1950
# 235       Lenovo    2         5       8             256   2236
# 236       Lenovo    3         5       6             256    883
# 237      Toshiba    2         5       8             256   1499
#
# [238 rows x 6 columns]

# %%
print(new_data.columns)
# Out:
# Index(['Manufacturer', 'GPU', 'CPU_core', 'RAM_GB', 'Storage_GB_SSD', 'Price'], dtype='object')

# %%
encoder= OneHotEncoder()

# %%
manufacturer_2d = new_data['Manufacturer'].values.reshape(-1,1)

# %%
new_manufacturer=encoder.fit_transform(manufacturer_2d)

# %%
array_encoded_manufacturer = new_manufacturer.toarray()

# %%
new_data.drop(columns=['Manufacturer'], inplace=True)  # Drop the original column
new_data[encoder.get_feature_names_out(['Manufacturer'])] = array_encoded_manufacturer  # Add the encoded columns

# Optionally, you can convert the encoded columns to integers if needed
new_data[encoder.get_feature_names_out(['Manufacturer'])] = new_data[encoder.get_feature_names_out(['Manufacturer'])].astype(int)

# Display the updated DataFrame
print(new_data)
print(new_data.columns)
# Out:
#      GPU  CPU_core  RAM_GB  Storage_GB_SSD  Price  Manufacturer_Acer  \
# 0      2         5       8             256    978                  1
# 1      1         3       4             256    634                  0
# 2      1         7       8             256    946                  0
# 3      2         5       8             128   1244                  0
# 4      2         7       8             256    837                  0
# ..   ...       ...     ...             ...    ...                ...
# 233    2         7       8             256   1891                  0
# 234    2         5       8             256   1950                  0
# 235    2         5       8             256   2236                  0
# 236    3         5       6             256    883                  0
# 237    2         5       8             256   1499                  0
#
#      Manufacturer_Asus  Manufacturer_Dell  Manufacturer_HP  \
# 0                    0                  0                0
# ...

# %%
print(new_data.columns)
# Out:
# Index(['GPU', 'CPU_core', 'RAM_GB', 'Storage_GB_SSD', 'Price',
#        'Manufacturer_Acer', 'Manufacturer_Asus', 'Manufacturer_Dell',
#        'Manufacturer_HP', 'Manufacturer_Huawei', 'Manufacturer_Lenovo',
#        'Manufacturer_MSI', 'Manufacturer_Razer', 'Manufacturer_Samsung',
#        'Manufacturer_Toshiba', 'Manufacturer_Xiaomi'],
#       dtype='object')

# %%
x=new_data[['GPU', 'CPU_core', 'RAM_GB', 'Storage_GB_SSD', 'Manufacturer_Acer',
       'Manufacturer_Asus', 'Manufacturer_Dell', 'Manufacturer_HP',
       'Manufacturer_Huawei', 'Manufacturer_Lenovo', 'Manufacturer_MSI',
       'Manufacturer_Razer', 'Manufacturer_Samsung', 'Manufacturer_Toshiba',
       'Manufacturer_Xiaomi']]

# %%
y=new_data['Price']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=3/4,random_state=0)

# %%
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_test)

# %%
mse=mean_absolute_error(y_pred,y_test)
mse
# Out:
# 377.96904750742715
